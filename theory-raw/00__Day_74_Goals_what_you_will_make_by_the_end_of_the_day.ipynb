# %% [markdown]
# ## **0)— Day 74 Goals: what you will make by the end of the day**
#
# ### **Overview**
#
# Today’s lesson focuses on **aggregating and merging data in Pandas** while analysing a real-world **LEGO dataset**. By the end of the day, you will have explored LEGO’s product history, growth, and complexity using data manipulation techniques and visualisations.
#
# ---
#
# ### **Key Questions We Will Answer**
#
# * What is the **largest LEGO set ever created**, and how many parts did it contain?
# * In which year were the **first LEGO sets released**, and how many sets did LEGO sell in its first year?
# * Which **LEGO theme** has the most sets (e.g. Star Wars, Ninjago, Friends)?
# * When did LEGO **really take off** as a company based on product output?
# * How many **themes and sets** did LEGO release each year?
# * Have LEGO sets **increased in size and complexity** over time?
#
# ---
#
# ### **What You Will Learn Today**
#
# * How to combine **Jupyter Notebook Markdown with HTML**, including:
#
#   * Section headings
#   * Embedding images using the `<img>` tag
# * How to apply **Python slicing techniques** to Pandas DataFrames
# * How to **aggregate data** using:
#
#   * `.groupby()`
#   * `.count()`
#   * `.value_counts()`
#   * `.agg()`
# * How to **rename DataFrame columns** for clarity
# * How to create and customise:
#
#   * Line charts
#   * Scatter plots
#   * Bar charts
#   * Dual-axis plots in Matplotlib
# * How to understand and work with **relational database schemas**
#
#   * Primary keys
#   * Foreign keys
# * How to **merge DataFrames** that share a common key
#
# ---
#
# ### **Project Setup**
#
# * Download the provided **starter notebook and data files**
# * Add all `.csv` files (`colors.csv`, `sets.csv`, `themes.csv`) into a local `data/` folder
# * Ensure file paths are correct for **local Jupyter / VS Code** execution
#
# ---
#
# By the end of this lesson, you will have a complete, well-structured analysis notebook that combines **data aggregation, merging, and visualisation** to tell a clear story about LEGO’s evolution over time.
